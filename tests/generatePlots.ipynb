# %%
import os 

os.chdir('../ChatBall')

# %%
path = '../tests/sample_chats/sample04_.txt'

import process_chat

chat = process_chat.whatsAppChat(path) 
df = chat.chat_to_df()
chat.barChartTotal(df)
# Out:
# /home/pradeepj/repos/ChatBall/.venv/lib/python3.10/site-packages/IPython/core/pylabtools.py:152: UserWarning: Glyph 128104 (\N{MAN}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /home/pradeepj/repos/ChatBall/.venv/lib/python3.10/site-packages/IPython/core/pylabtools.py:152: UserWarning: Glyph 128105 (\N{WOMAN}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /home/pradeepj/repos/ChatBall/.venv/lib/python3.10/site-packages/IPython/core/pylabtools.py:152: UserWarning: Glyph 128102 (\N{BOY}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)

# %%
chat.overallMetrics(df)
# Out:
# (2054,
#  array([' Mum', ' Jana Family 👨\u200d👩\u200d👦\u200d👦', ' Dad', ' Pranav',
#         ' Pradeep', ' Dad India'], dtype=object),
#  [1340, 1, 526, 82, 89, 16])
